# %%
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %% [markdown]
# # line chart

# %%
df=pd.read_csv(r"C:\Users\Nandini Sharma\OneDrive\Desktop\data science\Mall_Customers.csv")
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df['Age'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Age'].plot()
# Out:
# <Axes: >

# %%
df['Annual Income (k$)'].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # scatter chart

# %%
df.plot(kind='scatter',x='Age',y='Annual Income (k$)')
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
df['Age'].corr(df['Annual Income (k$)'])
# Out:
# -0.012398042736060145

# %% [markdown]
# # Histogram

# %%
df['Annual Income (k$)'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['Age','Annual Income (k$)']].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['Age','Annual Income (k$)']].plot(kind='hist',bins=20,alpha=0.6)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # bar chart and barh chart

# %%
df['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
Rank_totals =round(df.groupby('Gender')["Annual Income (k$)"].mean(),2)
print(Rank_totals)
Rank_totals.plot(kind='bar')
# Out:
# Gender
# Female    59.25
# Male      62.23
# Name: Annual Income (k$), dtype: float64
# <Axes: xlabel='Gender'>

# %%
Rank_totals=df.groupby(['Gender'])[['Annual Income (k$)','Spending Score (1-100)']].mean()
print(Rank_totals)
Rank_totals.plot(kind='bar',alpha=0.5)
# Out:
#         Annual Income (k$)  Spending Score (1-100)
# Gender
# Female           59.250000               51.526786
# Male             62.227273               48.511364
# <Axes: xlabel='Gender'>

# %%
Rank_totals=df.groupby(['Gender'])[['Annual Income (k$)','Age']].mean()
print(Rank_totals)
Rank_totals.plot(kind='bar',alpha=0.5,stacked=True)
# Out:
#         Annual Income (k$)        Age
# Gender
# Female           59.250000  38.098214
# Male             62.227273  39.806818
# <Axes: xlabel='Gender'>

# %%
Rank_totals=df.groupby(['Gender'])[['Annual Income (k$)','Age']].mean()
print(Rank_totals)
Rank_totals.plot(kind='barh',alpha=0.5,stacked=True)
# Out:
#         Annual Income (k$)        Age
# Gender
# Female           59.250000  38.098214
# Male             62.227273  39.806818
# <Axes: ylabel='Gender'>

# %% [markdown]
# # Pie Chart

# %%
Rank_totals.plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='Annual Income (k$)'>, <Axes: ylabel='Age'>],
#       dtype=object)

# %%
Rank_totals.plot.bar(color =['green','Red'],subplots =True ,rot=45)
# Out:
# array([<Axes: title={'center': 'Annual Income (k$)'}, xlabel='Gender'>,
#        <Axes: title={'center': 'Age'}, xlabel='Gender'>], dtype=object)

# %% [markdown]
# # Box Plots

# %%
df['Annual Income (k$)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['Age','Annual Income (k$)']].plot(kind='box')
# Out:
# <Axes: >

# %%
q2=np.quantile(df['Annual Income (k$)'],0.5)
print('q2:',q2)
# Out:
# q2: 61.5

# %%
q1=np.quantile(df['Annual Income (k$)'],0.25)
print('q1',q1)
# Out:
# q1 41.5

# %%
q3=np.quantile(df['Annual Income (k$)'],0.75)
print('q3',q3)
# Out:
# q3 78.0

# %%
iqr=(q3-q1)
print('iqr',iqr)

[q3-1.5*iqr,q1-1.5*iqr]

min,max=q3-1.5*iqr,q1-1.5*iqr
iqrrange =[min,max]
iqrrange
# Out:
# iqr 36.5
# [23.25, -13.25]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
AI_in_range=df[(df['Annual Income (k$)']>= max) & (df['Annual Income (k$)']<= min)]
AI_in_range.count()
# Out:
# CustomerID                20
# Gender                    20
# Age                       20
# Annual Income (k$)        20
# Spending Score (1-100)    20
# dtype: int64

# %%
AI_in_range['Annual Income (k$)'].plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
AI_in_range.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Arae plot

# %%
df[['Age','Spending Score (1-100)']].plot(kind='area',alpha=0.5)
# Out:
# <Axes: >

# %%
df['Age'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df[['Age','Annual Income (k$)']].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
import matplotlib.pyplot as plt


df.plot(kind='hexbin',x='Annual Income (k$)',y='Spending Score (1-100)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
df.plot(kind='hexbin' ,x='Annual Income (k$)',y='Spending Score (1-100)',gridsize=20,figsize=(6,4))
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
df.plot(kind='scatter',
         x='Annual Income (k$)',
         y='Spending Score (1-100)' ,
         figsize=(6,4),
        title='month salary and spended in month  infotrmation',
         xlabel='salary in rupee',
         ylabel='spended in month', 
         marker="D",
        color='green')
# Out:
# <Axes: title={'center': 'month salary and spended in month  infotrmation'}, xlabel='salary in rupee', ylabel='spended in month'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,alpha=1,figsize=(10,6))
# Out:
# array([[<Axes: xlabel='CustomerID', ylabel='CustomerID'>,
#         <Axes: xlabel='Age', ylabel='CustomerID'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='CustomerID'>,
#         <Axes: xlabel='Spending Score (1-100)', ylabel='CustomerID'>],
#        [<Axes: xlabel='CustomerID', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='Age'>,
#         <Axes: xlabel='Spending Score (1-100)', ylabel='Age'>],
#        [<Axes: xlabel='CustomerID', ylabel='Annual Income (k$)'>,
#         <Axes: xlabel='Age', ylabel='Annual Income (k$)'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='Annual Income (k$)'>,
#         <Axes: xlabel='Spending Score (1-100)', ylabel='Annual Income (k$)'>],
#        [<Axes: xlabel='CustomerID', ylabel='Spending Score (1-100)'>,
#         <Axes: xlabel='Age', ylabel='Spending Score (1-100)'>,
#         <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>,
# ...

# %%
from pandas.plotting import bootstrap_plot
bootstrap_plot(df['Annual Income (k$)'])

# %%
import matplotlib.pyplot as plt
#line plot
plt.plot(df['Annual Income (k$)'])

plt.show()

# %%
plt.bar(x = df['Annual Income (k$)'], height =df['Age'])
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style 

style.use('fivethirtyeight')
style.use('ggplot')

plt.plot(df['Spending Score (1-100)'],linewidth=3,c='b')
plt.scatter(df['Annual Income (k$)'],df['Spending Score (1-100)'],linewidth=1,marker='*',c='red',alpha=0.6)

plt.title('epic info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.hist(df.Age,edgecolor="blue")
# Out:
# (array([31., 19., 34., 29., 16., 26., 15., 10.,  6., 14.]),
#  array([18. , 23.2, 28.4, 33.6, 38.8, 44. , 49.2, 54.4, 59.6, 64.8, 70. ]),
#  <BarContainer object of 10 artists>)
